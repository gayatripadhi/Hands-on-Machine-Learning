# %%
import pandas as pd

# %%
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']

# %%
users = pd.read_csv('E:\TuriFiles\Recommender Systems\ml-100k\u.user', sep='|', names=u_cols, encoding='latin-1')

# %%
r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']

# %%
ratings = pd.read_csv('E:\TuriFiles\Recommender Systems\ml-100k\u.data', sep='\t', names=r_cols, encoding='latin-1')

# %%
i_cols = ['movie id', 'movie title' ,'release date','video release date', 'IMDb URL', 'unknown', 'Action', 'Adventure',
          'Animation','Children\'s','Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy','Film-Noir', 'Horror', 'Musical',
          'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western']

# %%
items = pd.read_csv('E:\TuriFiles\Recommender Systems\ml-100k\u.item', sep='|', names=i_cols, encoding='latin-1')

# %%
print users.shape
# Out:
# (943, 5)

# %%
users.head()
# Out:
#    user_id  age sex  occupation zip_code
# 0        1   24   M  technician    85711
# 1        2   53   F       other    94043
# 2        3   23   M      writer    32067
# 3        4   24   M  technician    43537
# 4        5   33   F       other    15213

# %%
print ratings.shape
# Out:
# (100000, 4)

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  unix_timestamp
# 0      196       242       3       881250949
# 1      186       302       3       891717742
# 2       22       377       1       878887116
# 3      244        51       2       880606923
# 4      166       346       1       886397596

# %%
print items.shape
# Out:
# (1682, 24)

# %%
items.head()
# Out:
#    movie id        movie title release date  video release date  \
# 0         1   Toy Story (1995)  01-Jan-1995                 NaN
# 1         2   GoldenEye (1995)  01-Jan-1995                 NaN
# 2         3  Four Rooms (1995)  01-Jan-1995                 NaN
# 3         4  Get Shorty (1995)  01-Jan-1995                 NaN
# 4         5     Copycat (1995)  01-Jan-1995                 NaN
#
#                                             IMDb URL  unknown  Action  \
# 0  http://us.imdb.com/M/title-exact?Toy%20Story%2...        0       0
# 1  http://us.imdb.com/M/title-exact?GoldenEye%20(...        0       1
# 2  http://us.imdb.com/M/title-exact?Four%20Rooms%...        0       0
# 3  http://us.imdb.com/M/title-exact?Get%20Shorty%...        0       1
# 4  http://us.imdb.com/M/title-exact?Copycat%20(1995)        0       0
#
#    Adventure  Animation  Children's   ...     Fantasy  Film-Noir  Horror  \
# 0          0          1           1   ...           0          0       0
# ...

# %%
ratings_base = pd.read_csv('E:\TuriFiles\Recommender Systems\ml-100k\ua.base', sep='\t', names=r_cols, encoding='latin-1')

# %%
ratings_test = pd.read_csv('E:\TuriFiles\Recommender Systems\ml-100k\ua.test', sep='\t', names=r_cols, encoding='latin-1')

# %%
ratings_base.shape, ratings_test.shape
# Out:
# ((90570, 4), (9430, 4))

# %%
import graphlab

# %%
train_data = graphlab.SFrame(ratings_base)
# Out:
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: C:\Users\User\AppData\Local\Temp\graphlab_server_1517924273.log.0
# This non-commercial license of GraphLab Create for academic use is assigned to padhigayatri.official@gmail.com and will expire on January 02, 2019.

# %%
test_data = graphlab.SFrame(ratings_test)

# %%
popularity_model = graphlab.popularity_recommender.create(train_data, user_id='user_id', item_id='movie_id', target='rating')
# Out:
# Recsys training: model = popularity
# ...
#     To use these columns in scoring predictions, use a model that allows the use of additional features.
# Preparing data set.
#     Data has 90570 observations with 943 users and 1680 items.
#     Data prepared in: 0.073004s
# 90570 observations to process; with 1680 unique items.

# %%
popularity_recomm = popularity_model.recommend(users=range(1,6),k=5)

# %%
popularity_recomm.print_rows(num_rows=25)
# Out:
# +---------+----------+-------+------+
# | user_id | movie_id | score | rank |
# +---------+----------+-------+------+
# |    1    |   1467   |  5.0  |  1   |
# |    1    |   1201   |  5.0  |  2   |
# |    1    |   1189   |  5.0  |  3   |
# |    1    |   1122   |  5.0  |  4   |
# |    1    |   814    |  5.0  |  5   |
# |    2    |   1467   |  5.0  |  1   |
# |    2    |   1201   |  5.0  |  2   |
# |    2    |   1189   |  5.0  |  3   |
# |    2    |   1122   |  5.0  |  4   |
# |    2    |   814    |  5.0  |  5   |
# |    3    |   1467   |  5.0  |  1   |
# |    3    |   1201   |  5.0  |  2   |
# |    3    |   1189   |  5.0  |  3   |
# |    3    |   1122   |  5.0  |  4   |
# |    3    |   814    |  5.0  |  5   |
# |    4    |   1467   |  5.0  |  1   |
# |    4    |   1201   |  5.0  |  2   |
# |    4    |   1189   |  5.0  |  3   |
# |    4    |   1122   |  5.0  |  4   |
# |    4    |   814    |  5.0  |  5   |
# |    5    |   1467   |  5.0  |  1   |
# |    5    |   1201   |  5.0  |  2   |
# ...

# %%
ratings_base.groupby(by='movie_id')['rating'].mean().sort_values(ascending=False).head(20)
# Out:
# movie_id
# 1500    5.000000
# 1293    5.000000
# 1122    5.000000
# 1189    5.000000
# 1656    5.000000
# 1201    5.000000
# 1599    5.000000
# 814     5.000000
# 1467    5.000000
# 1536    5.000000
# 1449    4.714286
# 1642    4.500000
# 1463    4.500000
# 1594    4.500000
# 1398    4.500000
# 114     4.491525
# 408     4.480769
# 169     4.476636
# 318     4.475836
# 483     4.459821
# Name: rating, dtype: float64

# %%
item_sim_model = graphlab.item_similarity_recommender.create(train_data, user_id='user_id', item_id='movie_id', target='rating', 
                                                             similarity_type='pearson')
# Out:
# Recsys training: model = item_similarity
# ...
#     To use these columns in scoring predictions, use a model that allows the use of additional features.
# Preparing data set.
#     Data has 90570 observations with 943 users and 1680 items.
#     Data prepared in: 0.062004s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 5ms                            | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# ...

# %%
item_sim_recomm = item_sim_model.recommend(users=range(1,6),k=5)
# Out:
# Finished training in 1.31907s

# %%
item_sim_recomm.print_rows(num_rows=25)
# Out:
# +---------+----------+-------+------+
# | user_id | movie_id | score | rank |
# +---------+----------+-------+------+
# |    1    |   1599   |  5.0  |  1   |
# |    1    |   1201   |  5.0  |  2   |
# |    1    |   1189   |  5.0  |  3   |
# |    1    |   1122   |  5.0  |  4   |
# |    1    |   814    |  5.0  |  5   |
# |    2    |   1599   |  5.0  |  1   |
# |    2    |   1201   |  5.0  |  2   |
# |    2    |   1189   |  5.0  |  3   |
# |    2    |   1122   |  5.0  |  4   |
# |    2    |   814    |  5.0  |  5   |
# |    3    |   1599   |  5.0  |  1   |
# |    3    |   1201   |  5.0  |  2   |
# |    3    |   1189   |  5.0  |  3   |
# |    3    |   1122   |  5.0  |  4   |
# |    3    |   814    |  5.0  |  5   |
# |    4    |   1599   |  5.0  |  1   |
# |    4    |   1201   |  5.0  |  2   |
# |    4    |   1189   |  5.0  |  3   |
# |    4    |   1122   |  5.0  |  4   |
# |    4    |   814    |  5.0  |  5   |
# |    5    |   1599   |  5.0  |  1   |
# |    5    |   1201   |  5.0  |  2   |
# ...

# %%
model_performance = graphlab.compare(test_data, [popularity_model, item_sim_model])
# Out:
# PROGRESS: Evaluate model M0
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+-------------------+
# | cutoff |   mean_precision  |    mean_recall    |
# +--------+-------------------+-------------------+
# |   1    |  0.00106044538706 | 0.000106044538706 |
# |   2    | 0.000530222693531 | 0.000106044538706 |
# |   3    | 0.000353481795688 | 0.000106044538706 |
# |   4    | 0.000265111346766 | 0.000106044538706 |
# |   5    | 0.000212089077413 | 0.000106044538706 |
# |   6    | 0.000353481795688 | 0.000212089077413 |
# |   7    | 0.000302984396304 | 0.000212089077413 |
# |   8    | 0.000265111346766 | 0.000212089077413 |
# |   9    | 0.000235654530458 | 0.000212089077413 |
# |   10   | 0.000212089077413 | 0.000212089077413 |
# +--------+-------------------+-------------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M1
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+-------------------+
# ...

# %%
graphlab.show_comparison(model_performance,[popularity_model, item_sim_model])
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:59497/index.html
# Opening Canvas in default web browser.
